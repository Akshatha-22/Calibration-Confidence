# %% [markdown]
# ## WIP: end-to-end analysis notebook\n
# \n
# This notebook is a placeholder/draft for a fuller pipeline (data loading → training → calibration analysis).\n
# It’s marked **WIP** because parts of the pipeline may change as the project evolves.\n

# %%
import os
import sys
from pathlib import Path

# Move to repo root (local assumption: notebook is in repo_root/notebooks)\n
os.chdir(Path.cwd().parent)

ROOT = os.path.abspath(os.getcwd())
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

print("Repo root:", os.getcwd())
